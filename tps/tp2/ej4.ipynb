# %%
import simpy
import random
import numpy as np

simulation_time = 7*60*60
cola = 0
cola_max = 0
tiempo_ultima_atencion = 0
tiempo_maximo_espera = 0


def getLambda(env):
    if(env.now <= 2*60*60):
        return 1/240
    elif(env.now <= 5*60*60):
        return 1/120
    elif(env.now <= 7*60*60):
        return 1/360
    
    
def duracionAtencion():
    u = np.random.uniform()
    if(u <= 0.1):
        return np.random.uniform(1,7) * 60
    elif(u <= 0.8):
        return np.random.uniform(1,3) * 60
    return np.random.uniform(1,5) * 60
    
def cajero(env):
    global cola
    index = 1
    atm = simpy.Resource(env, capacity=1)
    while True:
        arriboClientes = random.expovariate(getLambda(env))
        yield env.timeout(arriboClientes)
        print('llega un cliente')
        cola +=1
        print('cola en el cajero', cola)
        env.process(atencion(env, index, atm))
        index +=1

def atencion(env, index, atm):
    global cola, cola_max, tiempo_ultima_atencion, tiempo_maximo_espera
    request = atm.request()
    yield request
    duracion =  duracionAtencion()
    yield env.timeout(duracion)
    atm.release(request)
    print('Uso el cajero')
    
    #Chuequeo la cola maxima
    if cola > cola_max: cola_max = cola
    
    print('cola antes de atender al cliente:', cola)
    cola -= 1
    print("Cola despues de la atencion:", cola)
    
    #Chequeo la cantidad maxima de espera
    if (round(env.now/60, 2) - tiempo_ultima_atencion > tiempo_maximo_espera):
        tiempo_maximo_espera = round(env.now/60, 2) - tiempo_ultima_atencion
        tiempo_ultima_atencion = round(env.now/60, 2)
    
environment = simpy.Environment()
environment.process(cajero(environment))
environment.run(until=simulation_time)

print('\nLa cola maxima que se formo fue de ' + str(cola_max) + ' personas.')
print('La cantidad maxima de espera de un cliente fue ' + str(round(tiempo_maximo_espera, 2)) + ' minutos.')
# Out:
# llega un cliente
# cola en el cajero 1
# llega un cliente
# cola en el cajero 2
# Uso el cajero
# cola antes de atender al cliente: 2
# Cola despues de la atencion: 1
# Uso el cajero
# cola antes de atender al cliente: 1
# Cola despues de la atencion: 0
# llega un cliente
# cola en el cajero 1
# Uso el cajero
# cola antes de atender al cliente: 1
# Cola despues de la atencion: 0
# llega un cliente
# cola en el cajero 1
# Uso el cajero
# cola antes de atender al cliente: 1
# Cola despues de la atencion: 0
# llega un cliente
# cola en el cajero 1
# Uso el cajero
# cola antes de atender al cliente: 1
# Cola despues de la atencion: 0
# llega un cliente
# cola en el cajero 1
# Uso el cajero
# cola antes de atender al cliente: 1
# Cola despues de la atencion: 0
# llega un cliente
# cola en el cajero 1
# Uso el cajero
# cola antes de atender al cliente: 1
# Cola despues de la atencion: 0
# llega un cliente
# cola en el cajero 1
# llega un cliente
# cola en el cajero 2
# llega un cliente
# cola en el cajero 3
# Uso el cajero
# cola antes de atender al cliente: 3
# Cola despues de la atencion: 2
# Uso el cajero
# cola antes de atender al cliente: 2
# Cola despues de la atencion: 1
# Uso el cajero
# cola antes de atender al cliente: 1
# Cola despues de la atencion: 0
# llega un cliente
# cola en el cajero 1
# llega un cliente
# cola en el cajero 2
# Uso el cajero
# cola antes de atender al cliente: 2
# Cola despues de la atencion: 1
# llega un cliente
# cola en el cajero 2
# Uso el cajero
# cola antes de atender al cliente: 2
# Cola despues de la atencion: 1
# Uso el cajero
# cola antes de atender al cliente: 1
# Cola despues de la atencion: 0
# llega un cliente
# cola en el cajero 1
# Uso el cajero
# cola antes de atender al cliente: 1
# Cola despues de la atencion: 0
# llega un cliente
# cola en el cajero 1
# llega un cliente
# cola en el cajero 2
# Uso el cajero
# cola antes de atender al cliente: 2
# Cola despues de la atencion: 1
# llega un cliente
# cola en el cajero 2
# Uso el cajero
# cola antes de atender al cliente: 2
# Cola despues de la atencion: 1
# Uso el cajero
# cola antes de atender al cliente: 1
# Cola despues de la atencion: 0
# llega un cliente
# cola en el cajero 1
# llega un cliente
# cola en el cajero 2
# llega un cliente
# cola en el cajero 3
# Uso el cajero
# cola antes de atender al cliente: 3
# Cola despues de la atencion: 2
# Uso el cajero
# cola antes de atender al cliente: 2
# Cola despues de la atencion: 1
# llega un cliente
# cola en el cajero 2
# Uso el cajero
# cola antes de atender al cliente: 2
# Cola despues de la atencion: 1
# Uso el cajero
# cola antes de atender al cliente: 1
# Cola despues de la atencion: 0
# llega un cliente
# cola en el cajero 1
# Uso el cajero
# cola antes de atender al cliente: 1
# Cola despues de la atencion: 0
# llega un cliente
# cola en el cajero 1
# Uso el cajero
# cola antes de atender al cliente: 1
# Cola despues de la atencion: 0
# llega un cliente
# cola en el cajero 1
# Uso el cajero
# cola antes de atender al cliente: 1
# Cola despues de la atencion: 0
# llega un cliente
# cola en el cajero 1
# llega un cliente
# cola en el cajero 2
# Uso el cajero
# cola antes de atender al cliente: 2
# Cola despues de la atencion: 1
# Uso el cajero
# cola antes de atender al cliente: 1
# Cola despues de la atencion: 0
# llega un cliente
# cola en el cajero 1
# llega un cliente
# cola en el cajero 2
# Uso el cajero
# cola antes de atender al cliente: 2
# Cola despues de la atencion: 1
# llega un cliente
# cola en el cajero 2
# llega un cliente
# cola en el cajero 3
# Uso el cajero
# cola antes de atender al cliente: 3
# Cola despues de la atencion: 2
# llega un cliente
# cola en el cajero 3
# Uso el cajero
# cola antes de atender al cliente: 3
# Cola despues de la atencion: 2
# Uso el cajero
# cola antes de atender al cliente: 2
# Cola despues de la atencion: 1
# llega un cliente
# cola en el cajero 2
# Uso el cajero
# cola antes de atender al cliente: 2
# Cola despues de la atencion: 1
# Uso el cajero
# cola antes de atender al cliente: 1
# Cola despues de la atencion: 0
# llega un cliente
# cola en el cajero 1
# llega un cliente
# cola en el cajero 2
# Uso el cajero
# cola antes de atender al cliente: 2
# Cola despues de la atencion: 1
# llega un cliente
# cola en el cajero 2
# Uso el cajero
# cola antes de atender al cliente: 2
# Cola despues de la atencion: 1
# Uso el cajero
# cola antes de atender al cliente: 1
# Cola despues de la atencion: 0
# llega un cliente
# cola en el cajero 1
# Uso el cajero
# cola antes de atender al cliente: 1
# Cola despues de la atencion: 0
# llega un cliente
# cola en el cajero 1
# Uso el cajero
# cola antes de atender al cliente: 1
# Cola despues de la atencion: 0
# llega un cliente
# cola en el cajero 1
# llega un cliente
# cola en el cajero 2
# llega un cliente
# cola en el cajero 3
# llega un cliente
# cola en el cajero 4
# llega un cliente
# cola en el cajero 5
# Uso el cajero
# cola antes de atender al cliente: 5
# Cola despues de la atencion: 4
# Uso el cajero
# cola antes de atender al cliente: 4
# Cola despues de la atencion: 3
# llega un cliente
# cola en el cajero 4
# Uso el cajero
# cola antes de atender al cliente: 4
# Cola despues de la atencion: 3
# Uso el cajero
# cola antes de atender al cliente: 3
# Cola despues de la atencion: 2
# Uso el cajero
# cola antes de atender al cliente: 2
# Cola despues de la atencion: 1
# Uso el cajero
# cola antes de atender al cliente: 1
# Cola despues de la atencion: 0
# llega un cliente
# cola en el cajero 1
# llega un cliente
# cola en el cajero 2
# llega un cliente
# cola en el cajero 3
# Uso el cajero
# cola antes de atender al cliente: 3
# Cola despues de la atencion: 2
# llega un cliente
# cola en el cajero 3
# llega un cliente
# cola en el cajero 4
# Uso el cajero
# cola antes de atender al cliente: 4
# Cola despues de la atencion: 3
# llega un cliente
# cola en el cajero 4
# Uso el cajero
# cola antes de atender al cliente: 4
# Cola despues de la atencion: 3
# llega un cliente
# cola en el cajero 4
# llega un cliente
# cola en el cajero 5
# llega un cliente
# cola en el cajero 6
# Uso el cajero
# cola antes de atender al cliente: 6
# Cola despues de la atencion: 5
# llega un cliente
# cola en el cajero 6
# Uso el cajero
# cola antes de atender al cliente: 6
# Cola despues de la atencion: 5
# llega un cliente
# cola en el cajero 6
# Uso el cajero
# cola antes de atender al cliente: 6
# Cola despues de la atencion: 5
# Uso el cajero
# cola antes de atender al cliente: 5
# Cola despues de la atencion: 4
# Uso el cajero
# cola antes de atender al cliente: 4
# Cola despues de la atencion: 3
# Uso el cajero
# cola antes de atender al cliente: 3
# Cola despues de la atencion: 2
# llega un cliente
# cola en el cajero 3
# llega un cliente
# cola en el cajero 4
# Uso el cajero
# cola antes de atender al cliente: 4
# Cola despues de la atencion: 3
# llega un cliente
# cola en el cajero 4
# Uso el cajero
# cola antes de atender al cliente: 4
# Cola despues de la atencion: 3
# Uso el cajero
# cola antes de atender al cliente: 3
# Cola despues de la atencion: 2
# Uso el cajero
# cola antes de atender al cliente: 2
# Cola despues de la atencion: 1
# llega un cliente
# cola en el cajero 2
# Uso el cajero
# cola antes de atender al cliente: 2
# Cola despues de la atencion: 1
# llega un cliente
# cola en el cajero 2
# Uso el cajero
# cola antes de atender al cliente: 2
# Cola despues de la atencion: 1
# llega un cliente
# cola en el cajero 2
# llega un cliente
# cola en el cajero 3
# llega un cliente
# cola en el cajero 4
# llega un cliente
# cola en el cajero 5
# llega un cliente
# cola en el cajero 6
# Uso el cajero
# cola antes de atender al cliente: 6
# Cola despues de la atencion: 5
# llega un cliente
# cola en el cajero 6
# Uso el cajero
# cola antes de atender al cliente: 6
# Cola despues de la atencion: 5
# llega un cliente
# cola en el cajero 6
# llega un cliente
# cola en el cajero 7
# llega un cliente
# cola en el cajero 8
# Uso el cajero
# cola antes de atender al cliente: 8
# Cola despues de la atencion: 7
# llega un cliente
# cola en el cajero 8
# llega un cliente
# cola en el cajero 9
# Uso el cajero
# cola antes de atender al cliente: 9
# Cola despues de la atencion: 8
# Uso el cajero
# cola antes de atender al cliente: 8
# Cola despues de la atencion: 7
# llega un cliente
# cola en el cajero 8
# Uso el cajero
# cola antes de atender al cliente: 8
# Cola despues de la atencion: 7
# llega un cliente
# cola en el cajero 8
# llega un cliente
# cola en el cajero 9
# llega un cliente
# cola en el cajero 10
# Uso el cajero
# cola antes de atender al cliente: 10
# Cola despues de la atencion: 9
# llega un cliente
# cola en el cajero 10
# llega un cliente
# cola en el cajero 11
# Uso el cajero
# cola antes de atender al cliente: 11
# Cola despues de la atencion: 10
# Uso el cajero
# cola antes de atender al cliente: 10
# Cola despues de la atencion: 9
# llega un cliente
# cola en el cajero 10
# Uso el cajero
# cola antes de atender al cliente: 10
# Cola despues de la atencion: 9
# Uso el cajero
# cola antes de atender al cliente: 9
# Cola despues de la atencion: 8
# llega un cliente
# cola en el cajero 9
# Uso el cajero
# cola antes de atender al cliente: 9
# Cola despues de la atencion: 8
# llega un cliente
# cola en el cajero 9
# llega un cliente
# cola en el cajero 10
# Uso el cajero
# cola antes de atender al cliente: 10
# Cola despues de la atencion: 9
# llega un cliente
# cola en el cajero 10
# Uso el cajero
# cola antes de atender al cliente: 10
# Cola despues de la atencion: 9
# Uso el cajero
# cola antes de atender al cliente: 9
# Cola despues de la atencion: 8
# llega un cliente
# cola en el cajero 9
# llega un cliente
# cola en el cajero 10
# Uso el cajero
# cola antes de atender al cliente: 10
# Cola despues de la atencion: 9
# llega un cliente
# cola en el cajero 10
# llega un cliente
# cola en el cajero 11
# Uso el cajero
# cola antes de atender al cliente: 11
# Cola despues de la atencion: 10
# Uso el cajero
# cola antes de atender al cliente: 10
# Cola despues de la atencion: 9
# llega un cliente
# cola en el cajero 10
# Uso el cajero
# cola antes de atender al cliente: 10
# Cola despues de la atencion: 9
# Uso el cajero
# cola antes de atender al cliente: 9
# Cola despues de la atencion: 8
# llega un cliente
# cola en el cajero 9
# llega un cliente
# cola en el cajero 10
# Uso el cajero
# cola antes de atender al cliente: 10
# Cola despues de la atencion: 9
# llega un cliente
# cola en el cajero 10
# llega un cliente
# cola en el cajero 11
# llega un cliente
# cola en el cajero 12
# Uso el cajero
# cola antes de atender al cliente: 12
# Cola despues de la atencion: 11
# llega un cliente
# cola en el cajero 12
# llega un cliente
# cola en el cajero 13
# llega un cliente
# cola en el cajero 14
# Uso el cajero
# cola antes de atender al cliente: 14
# Cola despues de la atencion: 13
# Uso el cajero
# cola antes de atender al cliente: 13
# Cola despues de la atencion: 12
# llega un cliente
# cola en el cajero 13
# Uso el cajero
# cola antes de atender al cliente: 13
# Cola despues de la atencion: 12
# Uso el cajero
# cola antes de atender al cliente: 12
# Cola despues de la atencion: 11
# llega un cliente
# cola en el cajero 12
# llega un cliente
# cola en el cajero 13
# llega un cliente
# cola en el cajero 14
# llega un cliente
# cola en el cajero 15
# Uso el cajero
# cola antes de atender al cliente: 15
# Cola despues de la atencion: 14
# llega un cliente
# cola en el cajero 15
# Uso el cajero
# cola antes de atender al cliente: 15
# Cola despues de la atencion: 14
# llega un cliente
# cola en el cajero 15
# llega un cliente
# cola en el cajero 16
# llega un cliente
# cola en el cajero 17
# Uso el cajero
# cola antes de atender al cliente: 17
# Cola despues de la atencion: 16
# llega un cliente
# cola en el cajero 17
# Uso el cajero
# cola antes de atender al cliente: 17
# Cola despues de la atencion: 16
# llega un cliente
# cola en el cajero 17
# llega un cliente
# cola en el cajero 18
# Uso el cajero
# cola antes de atender al cliente: 18
# Cola despues de la atencion: 17
# llega un cliente
# cola en el cajero 18
# Uso el cajero
# cola antes de atender al cliente: 18
# Cola despues de la atencion: 17
# llega un cliente
# cola en el cajero 18
# Uso el cajero
# cola antes de atender al cliente: 18
# Cola despues de la atencion: 17
# llega un cliente
# cola en el cajero 18
# Uso el cajero
# cola antes de atender al cliente: 18
# Cola despues de la atencion: 17
# llega un cliente
# cola en el cajero 18
# llega un cliente
# cola en el cajero 19
# llega un cliente
# cola en el cajero 20
# Uso el cajero
# cola antes de atender al cliente: 20
# Cola despues de la atencion: 19
# llega un cliente
# cola en el cajero 20
# llega un cliente
# cola en el cajero 21
# Uso el cajero
# cola antes de atender al cliente: 21
# Cola despues de la atencion: 20
# llega un cliente
# cola en el cajero 21
# Uso el cajero
# cola antes de atender al cliente: 21
# Cola despues de la atencion: 20
# llega un cliente
# cola en el cajero 21
# llega un cliente
# cola en el cajero 22
# Uso el cajero
# cola antes de atender al cliente: 22
# Cola despues de la atencion: 21
# llega un cliente
# cola en el cajero 22
# Uso el cajero
# cola antes de atender al cliente: 22
# Cola despues de la atencion: 21
# llega un cliente
# cola en el cajero 22
# Uso el cajero
# cola antes de atender al cliente: 22
# Cola despues de la atencion: 21
# Uso el cajero
# cola antes de atender al cliente: 21
# Cola despues de la atencion: 20
# llega un cliente
# cola en el cajero 21
# Uso el cajero
# cola antes de atender al cliente: 21
# Cola despues de la atencion: 20
# Uso el cajero
# cola antes de atender al cliente: 20
# Cola despues de la atencion: 19
# llega un cliente
# cola en el cajero 20
# Uso el cajero
# cola antes de atender al cliente: 20
# Cola despues de la atencion: 19
# Uso el cajero
# cola antes de atender al cliente: 19
# Cola despues de la atencion: 18
# llega un cliente
# cola en el cajero 19
# Uso el cajero
# cola antes de atender al cliente: 19
# Cola despues de la atencion: 18
# Uso el cajero
# cola antes de atender al cliente: 18
# Cola despues de la atencion: 17
# Uso el cajero
# cola antes de atender al cliente: 17
# Cola despues de la atencion: 16
# llega un cliente
# cola en el cajero 17
# Uso el cajero
# cola antes de atender al cliente: 17
# Cola despues de la atencion: 16
# Uso el cajero
# cola antes de atender al cliente: 16
# Cola despues de la atencion: 15
# llega un cliente
# cola en el cajero 16
# Uso el cajero
# cola antes de atender al cliente: 16
# Cola despues de la atencion: 15
# llega un cliente
# cola en el cajero 16
# Uso el cajero
# cola antes de atender al cliente: 16
# Cola despues de la atencion: 15
# Uso el cajero
# cola antes de atender al cliente: 15
# Cola despues de la atencion: 14
# Uso el cajero
# cola antes de atender al cliente: 14
# Cola despues de la atencion: 13
# llega un cliente
# cola en el cajero 14
# Uso el cajero
# cola antes de atender al cliente: 14
# Cola despues de la atencion: 13
# llega un cliente
# cola en el cajero 14
# Uso el cajero
# cola antes de atender al cliente: 14
# Cola despues de la atencion: 13
# Uso el cajero
# cola antes de atender al cliente: 13
# Cola despues de la atencion: 12
# Uso el cajero
# cola antes de atender al cliente: 12
# Cola despues de la atencion: 11
# Uso el cajero
# cola antes de atender al cliente: 11
# Cola despues de la atencion: 10
# Uso el cajero
# cola antes de atender al cliente: 10
# Cola despues de la atencion: 9
# Uso el cajero
# cola antes de atender al cliente: 9
# Cola despues de la atencion: 8
# Uso el cajero
# cola antes de atender al cliente: 8
# Cola despues de la atencion: 7
# Uso el cajero
# cola antes de atender al cliente: 7
# Cola despues de la atencion: 6
# llega un cliente
# cola en el cajero 7
# llega un cliente
# cola en el cajero 8
# llega un cliente
# cola en el cajero 9
# Uso el cajero
# cola antes de atender al cliente: 9
# Cola despues de la atencion: 8
# llega un cliente
# cola en el cajero 9
# Uso el cajero
# cola antes de atender al cliente: 9
# Cola despues de la atencion: 8
# Uso el cajero
# cola antes de atender al cliente: 8
# Cola despues de la atencion: 7
# Uso el cajero
# cola antes de atender al cliente: 7
# Cola despues de la atencion: 6
# llega un cliente
# cola en el cajero 7
# Uso el cajero
# cola antes de atender al cliente: 7
# Cola despues de la atencion: 6
# Uso el cajero
# cola antes de atender al cliente: 6
# Cola despues de la atencion: 5
# llega un cliente
# cola en el cajero 6
# llega un cliente
# cola en el cajero 7
# Uso el cajero
# cola antes de atender al cliente: 7
# Cola despues de la atencion: 6
# Uso el cajero
# cola antes de atender al cliente: 6
# Cola despues de la atencion: 5
# llega un cliente
# cola en el cajero 6
# llega un cliente
# cola en el cajero 7
# Uso el cajero
# cola antes de atender al cliente: 7
# Cola despues de la atencion: 6
# Uso el cajero
# cola antes de atender al cliente: 6
# Cola despues de la atencion: 5
# llega un cliente
# cola en el cajero 6
# Uso el cajero
# cola antes de atender al cliente: 6
# Cola despues de la atencion: 5
# llega un cliente
# cola en el cajero 6
# Uso el cajero
# cola antes de atender al cliente: 6
# Cola despues de la atencion: 5
# Uso el cajero
# cola antes de atender al cliente: 5
# Cola despues de la atencion: 4
# Uso el cajero
# cola antes de atender al cliente: 4
# Cola despues de la atencion: 3
# Uso el cajero
# cola antes de atender al cliente: 3
# Cola despues de la atencion: 2
# Uso el cajero
# cola antes de atender al cliente: 2
# Cola despues de la atencion: 1
# llega un cliente
# cola en el cajero 2
# Uso el cajero
# cola antes de atender al cliente: 2
# Cola despues de la atencion: 1
# Uso el cajero
# cola antes de atender al cliente: 1
# Cola despues de la atencion: 0
# llega un cliente
# cola en el cajero 1
# Uso el cajero
# cola antes de atender al cliente: 1
# Cola despues de la atencion: 0
# llega un cliente
# cola en el cajero 1
# Uso el cajero
# cola antes de atender al cliente: 1
# Cola despues de la atencion: 0
# llega un cliente
# cola en el cajero 1
# Uso el cajero
# cola antes de atender al cliente: 1
# Cola despues de la atencion: 0
#
# La cola maxima que se formo fue de 22 personas.
# La cantidad maxima de espera de un cliente fue 37.32 minutos.
